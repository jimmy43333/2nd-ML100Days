# %% [markdown]
# ## 作業一
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# Dataset : Huge Stock Market Dataset(Historical daily prices and volumes of all U.S. stocks and ETFs)
#
# https://www.kaggle.com/borismarjanovic/price-volume-data-for-all-us-stocks-etfs
#
# 1. 你選的這組資料為何重要
# ```
# This dataset is the historical daily price and volume data for all US-based stocks. It is the well-prepared datasets that we can use to analysis the stock behavior, and it will be an extremely challenge to predict the future price of the stock market.
# ```
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# ```
# It is collected and organized into a pile of txt file by Boris Marjanovic.
# ```
# 3. 蒐集而來的資料型態為何
# ```
# The data is presented in CSV format with seven columns: Date,Open,High,Low,Close,Volume,OpenInt. The data is stored as the txt file, the date format is Year-Month-Day, and other value are all float.
# ```
# 4. 這組資料想解決的問題如何評估
# ```
# We always hope that we can make a great prediction of the price of stock market. An accuracy prediction may offer some help for us making a proper decision to entry and out of the market.
# ```

# %% [markdown]
# ## 作業二
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# ```
# 減少司機在載客前的行使距離,根據乘客上車的熱點分佈,推薦給司機前往等待的地點
# ```
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# ```
# 紀錄乘客上車時間及位置
# 司機行使距離
# ```
# 3. 蒐集而來的資料型態為何
# ```
# datetime, google map location
# ```
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# ```
# 計算出司機接到載客通知到客人上車地點的行駛距離，以及行駛時間,並設法最小化
# ```

# %% [markdown]
# ## 作業三：練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime

# %%
def mean_squared_error(y,yp):
    mse = sum(np.square((y-yp)))/len(y)
    return mse

def mean_absolute_error(y,yp):
    mae = sum(abs(y-yp))/len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()
type(x_lin)
# Out:
# numpy.ndarray

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 261.381
# The Mean absolute error is 12.755

# %% [markdown]
# ## Practice
# 使用股票資料集，抓出收盤價,最高及最低價錢,已個百分之50相加,並與收盤價算MAE,MSE

# %%
file_data = open("./data/Stocks/a.us.txt","r+")
stock_data = file_data.readlines()
print(stock_data[0])

output = []
for ele in stock_data:
    tmp = ele.split(",")
    output.append(tmp)
w_h = 0.5
w_l = 1-w_h
stock_array = np.array(output)
time = pd.DatetimeIndex(stock_array[1:,0]).date
high_value = np.array(stock_array[1:,1],dtype=np.float64)
low_value = np.array(stock_array[1:,3],dtype=np.float64)
close_value = np.array(stock_array[1:,4],dtype=np.float64)
predict = high_value*w_h+low_value*w_l
plt.plot(time, close_value, 'b-', label = 'close value')
plt.plot(time, predict, 'r-', label = 'predict')
plt.title("The high value of the stock")
plt.legend(loc = 2)
plt.show()
# Out:
# Date,Open,High,Low,Close,Volume,OpenInt

# %%
MSE = mean_squared_error(close_value,predict)
MAE = mean_absolute_error(close_value,predict)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 0.652
# The Mean absolute error is 0.352

# %% [markdown]
# ## NOTE : np.array
# #### array屬性
# ```
# stock_array = np.array(stock_data)
# print("ndim:{0}".format(stock_array.ndim))
# print("size:{0}".format(stock_array.size))
# print("shape:{0}".format(stock_array.shape))
# print("dtype:{0}".format(stock_array.dtype))
# print("itemsize:{0}".format(stock_array.itemsize))
# print("data:{0}".format(stock_array.data))
# ```
# #### 一維陣列
# ```
# np.array([,,,])
# np.arange(start,end,step,type)
# ```
# #### 二維陣列
# ```
# np.array([,,,],[,,,],type)
# ```
# #### 其他宣告
# ```
# np.zeros((rows,cols))
# np.ones((rows,cols))
# np.empty((rows,cols))
# np.linespace(start,end,numbers of element)
# ```
