# %% [markdown]
# # NOTE: Matplotlib and Seaborn

# %% [markdown]
# 主要套件：
# 1.    Matplotlib
# 2.    Seaborn
# 3.    Plotly

# %% [markdown]
# ### Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot([1,2,3,4])
plt.xlabel("x label")
plt.ylabel("y label")
plt.plot([1,2,3,4],[5,6,7,8],'ro')
plt.show()

# %%
t = np.arange(0,5,0.2)
plt.plot(t,t,'r--',t,t*5,'bs',t,t**3,'g^')

# %%
x = np.arange(0,100,10)
y = np.random.rand(10)
plt.bar(x,y)
x2 = np.arange(0,100,1)
y2 = np.random.rand(100)
plt.scatter(x2,y2)

# %%
Tree = np.arange(0,500,1)
High = np.round(np.random.uniform(1,20,500),2)
Width = np.round(np.random.uniform(1,10,500),2)
Country = np.random.randint(0,3,500)
data_labels = ["TreeIndex","High(m)","Width(m)","Country"]
data_cols = [Tree,High,Width,Country]
dataframe = pd.DataFrame(dict(zip(data_labels,data_cols)))

color = {0:'r',1:'g',2:'b'}
dataframe.insert(4,column="color",value=dataframe["Country"].map(color))
dataframe.head(5)

dataframe.plot.scatter(x="High(m)",y="Width(m)",c=dataframe["color"])
dataframe.plot.bar(x="High(m)",y="Width(m)", rot=0)

# %%
plt.style.available
# Out:
# ['fivethirtyeight',
#  'grayscale',
#  'seaborn',
#  'fast',
#  'classic',
#  'seaborn-white',
#  'seaborn-pastel',
#  'seaborn-paper',
#  'seaborn-whitegrid',
#  'seaborn-ticks',
#  'seaborn-bright',
#  'ggplot',
#  'Solarize_Light2',
#  'seaborn-darkgrid',
#  '_classic_test',
#  'bmh',
#  'tableau-colorblind10',
#  'seaborn-muted',
#  'seaborn-dark',
#  'seaborn-notebook',
#  'seaborn-colorblind',
#  'seaborn-poster',
#  'seaborn-talk',
#  'dark_background',
#  'seaborn-deep',
#  'seaborn-dark-palette']

# %%
plt.style.use("bmh")
N=50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi*(15*np.random.rand(N))**2
plt.scatter(x,y,s=area,c=colors)

# %% [markdown]
# ### Seaborn

# %%
import seaborn as sns

# %%
Tree = np.arange(0,100,1)
High = np.round(np.random.uniform(1,20,100),2)
Width = np.round(np.random.uniform(1,10,100),2)
Country = np.random.randint(0,3,100)
data_labels = ["TreeIndex","High(m)","Width(m)","Country"]
data_cols = [Tree,High,Width,Country]
dataframe = pd.DataFrame(dict(zip(data_labels,data_cols)))

color = {0:'r',1:'g',2:'b'}
dataframe.insert(4,column="color",value=dataframe["Country"].map(color))
CountryName = {0:'Taiwan',1:'Japan',2:'China'}
dataframe["N"] = dataframe["Country"].map(CountryName)
sns.lmplot('High(m)','Width(m)',data=dataframe,fit_reg=False,hue='N')
dataframe.head(5)
# Out:
#    TreeIndex  High(m)  Width(m)  Country color       N
# 0          0     3.97      3.67        0     r  Taiwan
# 1          1     2.58      3.78        0     r  Taiwan
# 2          2    19.42      3.71        0     r  Taiwan
# 3          3    13.13      8.99        1     g   Japan
# 4          4    12.63      4.13        1     g   Japan

# %%
print(dataframe['High(m)'].describe())
sns.boxplot(x=dataframe['High(m)'])
# Out:
# count    100.000000
# mean       9.878700
# std        5.590882
# min        1.050000
# 25%        5.067500
# 50%        9.860000
# 75%       14.442500
# max       19.990000
# Name: High(m), dtype: float64

# %% [markdown]
# # Reference
# * [第2.5講：資料視覺化(Matplotlib, Seaborn, Plotly)](https://medium.com/jameslearningnote/%E8%B3%87%E6%96%99%E5%88%86%E6%9E%90-%E6%A9%9F%E5%99%A8%E5%AD%B8%E7%BF%92-%E7%AC%AC2-5%E8%AC%9B-%E8%B3%87%E6%96%99%E8%A6%96%E8%A6%BA%E5%8C%96-matplotlib-seaborn-plotly-75cd353d6d3f)
# * [Python 中用 matplotlib 绘制盒状图（Boxplots）和小提琴图（Violinplots）](http://blog.topspeedsnail.com/archives/737)
# * [Python實現箱形圖的繪製](https://www.itread01.com/content/1541665023.html)
